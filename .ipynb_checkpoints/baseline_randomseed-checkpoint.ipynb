# %%
import pickle
import agent_test
import environment_test
import runner_test
import graph
import logging
import numpy as np
import networkx as nx
import sys
from random import choice
import pandas as pd
# %matplotlib inline
import pickle
import colorsys

# %%
from torch_geometric.datasets import Planetoid
from torch_geometric.datasets import WebKB

# %%
def crea_graph_for_test(pgdataset):
    g = nx.Graph(list(np.array(pgdataset.edge_index).T))
    g_ = graph.Graph(graph_type='man',cur_n=g.number_of_nodes(), p=0, g=g)
    return g_

# %%
cora = Planetoid(root='data/Planetoid', name='Cora')[0]
cornell = WebKB(root='data/WebKB', name='Cornell')[0]
texas = WebKB(root='data/WebKB', name='Texas')[0]
wisconsin = WebKB(root='data/WebKB', name='Wisconsin')[0]

# %%
texas = crea_graph_for_test(texas)

# %%
j_dic = {0:texas}

# %%
g = nx.empty_graph(86)
g.add_edges_from([(35,1) ,(37,1 ),(18,2 ),(26,2 ),(32,2 ),(33,2 ),(66,2 ),(76,2 ),(7,3 ),(10,3 ),(16,3 ),(30,3 ),(44,3 ),(52,3 ),(57,3 ),(67,3 ),(75,3 ),(80,3 ),(53,4 ),(49,5 ),(60,5 ),(15,6 ),(40,6 ),(36,7 ),(20,8 ),(64,8 ),(23,9 ),(67,10) ,(46,11) ,(53,11) ,(33,12) ,(59,13) ,(51,14) ,(65,14) ,(40,15) ,(30,16) ,(25,17) ,(31,17) ,(66,17) ,(32,18) ,(66,18) ,(76,18) ,(84,19) ,(22,20) ,(40,20) ,(56,20) ,(64,20) ,(81,20) ,(40,21) ,(40,22) ,(36,23) ,(43,23) ,(33,24) ,(54,24) ,(33,26) ,(36,26) ,(86,26) ,(30,27) ,(41,27) ,(48,27) ,(30,28) ,(55,28) ,(74,28) ,(60,29) ,(41,30) ,(48,30) ,(55,30) ,(61,30) ,(62,30) ,(82,30) ,(83,30) ,(84,30) ,(66,31) ,(66,32) ,(76,32) ,(34,33) ,(36,33) ,(44,33) ,(58,33) ,(77,33) ,(86,33) ,(36,35) ,(37,35) ,(71,35) ,(42,36) ,(43,36) ,(44,36) ,(68,36) ,(73,36) ,(85,36) ,(39,38) ,(74,38) ,(74,39) ,(45,40) ,(54,40) ,(58,40) ,(48,41) ,(53,43) ,(69,43) ,(72,43) ,(79,43) ,(73,44) ,(80,44) ,(58,45) ,(59,45) ,(53,46) ,(49,47) ,(60,49) ,(61,49) ,(77,50) ,(69,53) ,(72,53) ,(79,53) ,(58,55) ,(59,55) ,(59,58) ,(81,63) ,(78,64) ,(84,65) ,(76,66) ,(77,70) ,(79,72) ,(83,82) ,(84,83) ]
                )

sandi_auths = graph.Graph(graph_type='man',cur_n=g.number_of_nodes(), p=0, g=g)
j_dic = {0:sandi_auths}

#0.1, 100

# %%
g = nx.empty_graph(380)
g.add_edges_from(
(737,533),(737,783),(737,300),(737,736),(737,784),(477,733),(787,786),(787,768),(758,757),(758,576),(758,603),(610,647),(610,799),(795,776),(795,692),(744,557),(744,726),(744,796),(742,791),(742,576),(742,743),(742,762),(742,505),(742,763),(742,764),(742,740),(800,767),(800,729),(801,653),(801,656),(479,569),(300,736),(704,689),(704,687),(696,697),(696,776),(774,775),(774,771),(721,726),(576,743),(576,757),(576,762),(576,505),(576,763),(576,764),(781,780),(781,779),(635,663),(769,770),(769,603),(769,539),(597,802),(597,803),(572,784),(572,565),(572,783),(572,533),(572,785),(572,729),(697,776),(730,698),(730,768),(730,732),(777,640),(775,771),(647,799),(732,698),(732,768),(746,747),(802,803),(689,687),(726,796),(733,625),(733,623),(533,784),(533,783),(505,762),(505,763),(505,764),(784,565),(784,783),(784,785),(764,762),(764,763),(625,623),(662,640),(698,768),(687,694),(670,792),(607,691),(607,692),(607,539),(607,715),(607,716),(607,770),(724,722),(750,702),(750,751),(750,753),(767,768),(767,729),(691,770),(691,539),(539,603),(539,770),(786,768),(715,692),(715,716),(762,763),(676,804),(676,681),(734,719),(791,740),(518,201),(482,792),(783,565),(780,779),(656,653),(751,753),(770,603),(785,565),(768,729),(716,692),(692,776)]
)
mapping = dict(zip(g, range(0, g.number_of_nodes())))
g = nx.relabel_nodes(g, mapping)

mammalia24 = graph.Graph(graph_type='man',cur_n=g.number_of_nodes(), p=0, g=g)
j_dic = {0:mammalia24}

#0.2, 50
net = 'mammalia24'

# %%
g.number_of_edges()
# Out:
# 418

# %%
lr = 1e-3
model = 'S2V_QN_1'
bs = 32
n_step = 3
use_cuda = False
environment_name = 'SIR'
verbose = True
node_n = 100
net = '_ba_3'
# seeds = [20,30,0]
#community = '_sf_4_3_05'
#net = '_er'
#net='_sf_4_3_05'
#net='_4_3_065'
#net='_sw_6'
#net = '_sw_6_01'

# %%
with open('data/graph_dic_'+str(10)+'_'+str(node_n)+ net,'rb') as f:
    graph_dic_ = pickle.load(f)

# %%
b = graph_dic[0].g

# %%
largest_cc = max(nx.connected_components(b), key=len)
a = b.subgraph(largest_cc).copy()

# %%
a=b

# %%
max(dict(nx.degree(a)).values())
# Out:
# 13

# %%
nx.average_clustering(a)
# Out:
# 0.19827644577644574

# %%
a.number_of_edges()
# Out:
# 418

# %%
a.number_of_nodes()
# Out:
# 283

# %%
nx.community.modularity(a, nx.community.greedy_modularity_communities(a))
# Out:
# 0.46073333333333333

# %%
nx.community.modularity(a, nx.community.greedy_modularity_communities(a))
# Out:
# 0.34253846789716696

# %%
nx.community.modularity(a, nx.community.asyn_fluidc(a,3))
# Out:
# 0.4942572689825437

# %%
nx.community.modularity(a, nx.community.greedy_modularity_communities(a))
# Out:
# 0.38936

# %%
nx.community.modularity(a, nx.community.greedy_modularity_communities(a))
# Out:
# 0.4766549814560788

# %%
nx.community.modularity(a, nx.community.greedy_modularity_communities(a))
# Out:
# 0.8386393997577196

# %%
nx.community.modularity(a, nx.community.greedy_modularity_communities(a))
# Out:
# 0.5427399533978103

# %%
nx.community.modularity(a, nx.community.greedy_modularity_communities(a))
# Out:
# 0.9299895835718054

# %%
nx.community.modularity(a, nx.community.greedy_modularity_communities(a))
# Out:
# 0.835207825816391

# %%
with open('community/m/graph_dic_community'+'_'+str(node_n)+net,'rb') as f:
    graph_dic_ = pickle.load(f)

# %%
graph_dic = graph_dic_

# %%
graph_dic = j_dic

# %%
graph_dic
# Out:
# {0: <graph.Graph at 0x7f5de9cb3fa0>,
#  1: <graph.Graph at 0x7f5de571acd0>,
#  2: <graph.Graph at 0x7f5de9cb3280>,
#  3: <graph.Graph at 0x7f5de9cb3bb0>,
#  4: <graph.Graph at 0x7f5de9cb35b0>,
#  5: <graph.Graph at 0x7f5de9cb3df0>,
#  6: <graph.Graph at 0x7f5de9cb3d00>,
#  7: <graph.Graph at 0x7f5de9cb3490>,
#  8: <graph.Graph at 0x7f5de9cb3550>,
#  9: <graph.Graph at 0x7f5de9cb3430>}

# %%
agent_class = agent_test.DQAgent(graph_dic, model, lr,bs,n_step,use_cuda)
#agent_class.load_model('./trained_models/model_2000_10_40baer_SIRAVG.pt')
agent_class.load_model('./trained_models/model_5000_5_40er.pt')
#agent_class.load_model('./trained_models/model_3000_5_100ba.pt')
# Out:
# /home/zhihao/Document/RLGNN/RLGNN/utils/config.py:6: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   model_config = yaml.load(config_file)

# %%
env_class = environment_test.Environment(graph_dic,environment_name,0.35)

# %%
my_runner = runner_test.Runner(env_class, agent_class, 50,verbose)

# %%
results = my_runner.evaluate(500,10)
# Out:
# --------------------------------------------------start evaluation--------------------------------------------------
# runtime for one graph is:  60.13779544830322
# runtime for one graph is:  67.98686814308167
# runtime for one graph is:  59.63813281059265
# runtime for one graph is:  64.09270596504211
# runtime for one graph is:  69.50626540184021
# runtime for one graph is:  67.64610719680786
# runtime for one graph is:  60.906495809555054
# runtime for one graph is:  55.921616077423096
# runtime for one graph is:  51.1675980091095
# runtime for one graph is:  56.575435638427734

# %% [markdown]
# # spreading similuation

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import networkx as nx
from random import choice
from random import sample
#import powerlaw
from random import shuffle
import EoN

# %%
def spread_on_Gs(G_list,ini_num,times,N,seeds=None,tau=1.2,gamma=1):
    com_nodes = (G_list[-1].nodes)
    report_times = np.linspace(0,600,81)

    initial_infecteds = sample(list(com_nodes),ini_num)
   # initial_infecteds = seeds
    #res = []
    for i in range(len(G_list)):
        S,I,R = simulate_spread_times(G_list[i],tau, gamma,times,initial_infecteds,report_times)
        res = ([report_times,S/N,I/N,R/N])
        
    return np.array(res)
                     

def simulate_spread_times(G,tau, gamma,times,ini_infecteds,report_times):
    Ssum = np.zeros(len(report_times))
    Isum = np.zeros(len(report_times))
    Rsum = np.zeros(len(report_times))
    iterations = times
    for counter in range(iterations):
        t, S, I, R = EoN.fast_SIR(G, tau, gamma, initial_infecteds = ini_infecteds)
        newS, newI, newR = EoN.subsample(report_times, t, S, I, R)    
        Ssum += newS
        Isum += newI
        Rsum += newR
    Save = Ssum / float(iterations)
    Iave = Isum / float(iterations)
    Rave = Rsum / float(iterations)
    return Save,Iave,Rave

# %%
g_index = 0

# %%
def get_reduced_graphs(graph_dict,selected_nodes):
    r_graphs = []
    for g_index in range(5):
        graphs = []
        g = graph_dic[g_index].g.copy()
        for i in selected_nodes[0][g_index]:
            g.remove_node(i)
        g_rein = g.copy()
        graphs.append(g_rein)

        g = graph_dic[g_index].g.copy()
        deg_dict = dict(g.degree())
        keys = sorted(deg_dict, key=lambda key: deg_dict[key])               
        g.remove_nodes_from(keys[-len(results[0][g_index]):])
        g_degree = g.copy()
        graphs.append(g_degree)
        
        g = graph_dic[g_index].g.copy()
        for _ in range(len(selected_nodes[0][g_index])):
            i = choice(list(g.nodes))
            g.remove_node(i)    
        g_random = g.copy()
        graphs.append(g_random)
        
        r_graphs.append(graphs)
    return r_graphs


def cal_edges(graphs):

    e_num = [0,0,0]
    for index in range(len(graphs)):
        e_num[0] += nx.number_of_edges(graphs[index][0])
        e_num[1] += nx.number_of_edges(graphs[index][1])
        e_num[2] += nx.number_of_edges(graphs[index][2])
    e_num[0] = e_num[0] / len(graphs)
    e_num[1] = e_num[1] / len(graphs)
    e_num[2] = e_num[2] / len(graphs)
    return e_num

def cal_shortest_path(graphs):

    e_num = [0,0,0]
    for index in range(len(graphs)):
        e_num[0] += cal_shortest_path_(graphs[index][0])
        e_num[1] += cal_shortest_path_(graphs[index][1])
        e_num[2] += cal_shortest_path_(graphs[index][2])
    e_num[0] = e_num[0] / len(graphs)
    e_num[1] = e_num[1] / len(graphs)
    e_num[2] = e_num[2] / len(graphs)
    return e_num


def cal_shortest_path_(G_o,p=1):
    largest_cc = max(nx.connected_components(G_o), key=len)
    G = G_o.subgraph(largest_cc).copy() 
    
    Nodes = G.nodes()
    num = math.ceil(p * nx.number_of_nodes(G))
    set_node = sample(Nodes,num)
    paths = []
    for t in set_node:
        path_node = nx.shortest_path_length(G,target=t)
        paths.append(path_node)
    pd_paths = pd.DataFrame(paths)
    shortes_p = pd_paths.mean(axis=1).mean()
    return shortes_p



def cal_l_component(graphs):

    e_num = [0,0,0]
    for index in range(len(graphs)):
        e_num[0] += len(max(nx.connected_components(graphs[index][0]), key=len))
        e_num[1] += len(max(nx.connected_components(graphs[index][1]), key=len))
        e_num[2] += len(max(nx.connected_components(graphs[index][2]), key=len))
    e_num[0] = e_num[0] / len(graphs)
    e_num[1] = e_num[1] / len(graphs)
    e_num[2] = e_num[2] / len(graphs)
    return e_num



def cal_epid_threshold(graphs):
    e_num = [0,0,0]
    for index in range(len(graphs)):
        e_num[0] += cal_epid_threshold_(graphs[index][0])
        e_num[1] += cal_epid_threshold_(graphs[index][1])
        e_num[2] += cal_epid_threshold_(graphs[index][2])
    e_num[0] = e_num[0] / len(graphs)
    e_num[1] = e_num[1] / len(graphs)
    e_num[2] = e_num[2] / len(graphs)
    return e_num    

def cal_epid_threshold_(G):
    ret = {}
    largest_cc = max(nx.connected_components(G), key=len)
    G_cc = G.subgraph(largest_cc).copy()
    degrees = [k for (n, k) in G_cc.degree]
    ret["k"]  = np.array(degrees).mean()
    ret["k2"] = np.array(degrees).var() + np.array(degrees).mean()**2
    return 1 / (ret["k2"]/ret["k"] - 1)

def cal_num_of_components(graphs):
    e_num = [0,0,0]
    for index in range(len(graphs)):
        e_num[0] += nx.number_connected_components(graphs[index][0])
        e_num[1] += nx.number_connected_components(graphs[index][1])
        e_num[2] += nx.number_connected_components(graphs[index][2])
    e_num[0] = e_num[0] / len(graphs)
    e_num[1] = e_num[1] / len(graphs)
    e_num[2] = e_num[2] / len(graphs)
    return e_num        



def cal_connectivity(graphs):

    e_num = [0,0,0]
    for index in range(len(graphs)):
        e_num[0] += nx.average_node_connectivity(graphs[index][0])
        e_num[1] += nx.average_node_connectivity(graphs[index][1])
        e_num[2] += nx.average_node_connectivity(graphs[index][2])
    e_num[0] = e_num[0] / len(graphs)
    e_num[1] = e_num[1] / len(graphs)
    e_num[2] = e_num[2] / len(graphs)
    return e_num

# %%
f_graphs = get_reduced_graphs(graph_dic,results)

# %%
with open('./results/tem_graphs/'+'f_graphs'+net+'.pkl','wb') as in_data:
    pickle.dump(f_graphs,in_data)

# %%
net
# Out:
# '_ba_3'

# %%
with open('./results/tem_graphs/'+'f_graphs'+net+'.pkl','rb') as out_data:
    f_graphs = pickle.load(out_data)

# %%
f_graphs
# Out:
# [[<networkx.classes.graph.Graph at 0x7f5de9cb3ee0>,
# ...

# %%
f_graphs[0][2].number_of_nodes()
# Out:
# 65

# %%
a = np.array([[30.6, 46.0, 62.4],
[0.3125, 0.6941346153846153, 2.140096153846154],
[18.2, 12.6, 3.2],
[0.7429629629629629, 0.5946722176632891, 0.3235365488912933],
[48.6, 59.4, 104.8]])

# %%
a = np.array([cal_l_component(f_graphs),
cal_connectivity(f_graphs),
cal_num_of_components(f_graphs),
cal_epid_threshold(f_graphs),
cal_edges(f_graphs)].copy())

# %%
a
# Out:
# array([[7.60000000e+00, 1.50000000e+01, 6.32000000e+01],
#        [3.27884615e-02, 7.75000000e-02, 2.29076923e+00],
#        [3.54000000e+01, 3.16000000e+01, 2.60000000e+00],
#        [1.06666667e+00, 9.55541126e-01, 1.96007842e-01],
#        [2.96000000e+01, 3.34000000e+01, 1.23200000e+02]])

# %%
b = list(a)
b = np.array(b)

# %%
#_er
b[0] = a[0]/10
b[1] = a[1]*3
b[2] = 1/a[2]*20
b[3] = 1/a[3]*2
b[4] = a[4]/15

# %%
#_ba_3
b[0] = a[0]/10
b[1] = a[1]*3
b[2] = 1/a[2]*18
b[3] = 1/a[3]*1.3
b[4] = a[4]/18

# %%
#_sw_6_01
b[0] = a[0]/10
b[1] = a[1]*3
b[2] = 1/a[2]*10
b[3] = 1/a[3]*2
b[4] = a[4]/18

# %%
#_4_3_065
b[0] = a[0]/10
b[1] = a[1]*3
b[2] = 1/a[2]*15
b[3] = 1/a[3]*3
b[4] = a[4]/15

# %%
#_sf_4_3_05
b[0] = a[0]/9
b[1] = a[1]*3.5
b[2] = 1/a[2]*40
b[3] = 1/a[3]*1.5
b[4] = a[4]/18

# %%
#netscience
b[0] = a[0]/30
b[1] = a[1]*13
b[2] = 1/a[2]*120
b[3] = 1/a[3]*1.1
b[4] = a[4]/100

# %%
#weaver
b[0] = a[0]/8
b[1] = a[1]*3
b[2] = 1/a[2]*15
b[3] = 1/a[3]*1.1
b[4] = a[4]/20

# %%
#weaver
b[0] = a[0]/64
b[1] = a[1]*3/8
b[2] = 1/a[2]*15/8
b[3] = 1/a[3]*1.1/8
b[4] = a[4]/20/8

# %%
#tortoise
b[0] = a[0]/4
b[1] = a[1]*120
b[2] = 1/a[2]*500
b[3] = 1/a[3]*2.5
b[4] = a[4]/40

# %%
#mammalia24
b[0] = a[0]/10
b[1] = a[1]*18
b[2] = 1/a[2]*120
b[3] = 1/a[3]*1.6
b[4] = a[4]/35

# %%
net
# Out:
# '_ba_3'

# %%
b
# Out:
# array([[0.76      , 1.5       , 6.32      ],
#        [0.09836538, 0.2325    , 6.87230769],
#        [0.50847458, 0.56962025, 6.92307692],
#        [1.21875   , 1.36048566, 6.63238771],
#        [1.64444444, 1.85555556, 6.84444444]])

# %%
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
 
# Set data
df = pd.DataFrame({
'group': ['Random','Max-degree','The proposed method'],
'\n \n Max-component size': b[0],
' '+' '+' '+' '+' '+' '+' Connectivity': b[1],
' '+' '+' '+' '+' '+'Inverse of \n component number': b[2],
'Inverse of'+' '+' '+' ' +' '+'\n epidemic threshold    ': b[3],
' Edges': b[4]
})
 
# ------- PART 1: Create background
 
# number of variable

with plt.style.context(['ieee']):

    fig, ax = plt.subplots(1,1,figsize=(4,2.5))
    categories=list(df)[1:]
    N = len(categories)
     
    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]
   
    # Initialise the spider plot
    ax = plt.subplot(111, polar=True,)
     
    # If you want the first axis to be on top:
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)
     
    # Draw one axe per variable + add labels
    plt.xticks(angles[:-1], categories,size=7)
    

     
    # Draw ylabels
    ax.set_rlabel_position(0)
    #plt.yticks([2,4,6], ['2','4','6'], color="grey", size=8)
    plt.yticks([2,4,6],[], color="grey", size=8)
    plt.ylim(0,8)
     
    
    # ------- PART 2: Add plots
     
    # Plot each individual = each line of the data
    # I don't make a loop, because plotting more than 3 groups makes the chart unreadable
     
    # Ind1
    values=df.loc[0].drop('group').values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, 'deepskyblue',linewidth=1.3, linestyle='solid', label="The proposed method")
    ax.fill(angles, values, 'deepskyblue', alpha=0.3)
     
    # Ind2
    values=df.loc[1].drop('group').values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, 'r',linewidth=1.3, linestyle='solid', label="Max-degree")
    ax.fill(angles, values, 'lightcoral', alpha=0.1)
    
    # Ind2
    values=df.loc[2].drop('group').values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values,'darkorange' ,linewidth=1.3, linestyle='solid', label="Random")
    ax.fill(angles, values, 'navajowhite', alpha=0.1)
     
    # Add legend
    plt.legend(loc='upper left',bbox_to_anchor=(-0.55, 1.1),fontsize=6,frameon=False)
    
    # Show the graph
    plt.show()
    fig.savefig("./pics/fig_radar"+net+"_01"+".pdf")

# %%
G_list = []
g = graph_dic[g_index].g.copy()
for i in results[0][g_index]:
    g.remove_node(i)
    g_ = g.copy()
    G_list.append(g_)

# %%
G_list_random = []
g = graph_dic[g_index].g.copy()
for _ in range(len(results[0][g_index])):
    i = choice(list(g.nodes))
#     while i in seeds:
#         i = choice(list(g.nodes))
    g.remove_node(i)
    g_ = g.copy()
    G_list_random.append(g_)

# %%
G_list_greedy_degree = []
g = graph_dic[g_index].g.copy()

#for _ in range(len(results[0][0])):
deg_dict = dict(g.degree())
    #max_key = max(deg_dict, key=lambda key: deg_dict[key])
    #print(max_key)
    #if max_key not in [3]:
        #i = choice(list(g.nodes))
keys = sorted(deg_dict, key=lambda key: deg_dict[key])
# for i in seeds:
#     keys.remove(i)
       
g.remove_nodes_from(keys[-len(results[0][g_index]):])
g_ = g.copy()
G_list_greedy_degree.append(g_)

# %%
G_list_greedy_degree[0].number_of_nodes()
# Out:
# 80

# %%
G_list_greedy_degree[0].number_of_edges()
# Out:
# 75

# %%
G_list[-1].number_of_edges()
# Out:
# 74

# %%
G_list[-1].number_of_nodes()
# Out:
# 80

# %%
nx.draw(G_list_random[-1],pos = nx.nx_agraph.graphviz_layout(G_list_random[-1], prog="neato"),with_labels=g.nodes)

# %%
nx.draw(G_list_greedy_degree[0],pos = nx.nx_agraph.graphviz_layout(G_list_greedy_degree[0], prog="neato"),with_labels=g.nodes)

# %%
nx.draw(G_list[-1],pos = nx.nx_agraph.graphviz_layout(G_list[-1], prog="neato"),with_labels=g.nodes)

# %%
nx.draw(graph_dic[g_index].g,pos = nx.nx_agraph.graphviz_layout(graph_dic[g_index].g, prog="neato"),with_labels=g.nodes)

# %%
#1 0.3
#0.2,0.01
#0.2.0.008 netscience 30 tortoise 25 weaver3


def hsl_to_rgb(h, s, l):
    h /= 360
    s /= 100
    l /= 100
    return colorsys.hls_to_rgb(h, l, s)

# Specify HSL color
hsl_navajowhite = (40, 90, 85)  # navajowhite in HSL
rgb_navajowhite = hsl_to_rgb(*hsl_navajowhite)

hsl_lightcoral = (5, 90, 78)  # navajowhite in HSL
rgb_lightcoral = hsl_to_rgb(*hsl_lightcoral)



with plt.style.context(['ieee']):
    fig, ax = plt.subplots(1,1,figsize=(5,3.5))
    tau = 0.2
    gamma = 0.01
    num = 3
    num_node = nx.number_of_nodes(graph_dic[0].g) - len(results[0][0])
    print(num_node)
#     f_graphs = get_reduced_graphs(graph_dic,results)
    num = int(num_node*0.1)
    
    f_res_list = []
    f_res_list_greedy_degree = []
    f_res_list_random = []
    
    all_f_res_list = []
    all_f_res_list_greedy_degree = []
    all_f_res_list_random = []    
    
    
    for index in range(5):

        res_list = spread_on_Gs([f_graphs[index][0]],num,50,num_node,tau=tau,gamma=gamma)
        all_f_res_list.append(spread_on_Gs([f_graphs[index][0]],num,50,num_node,tau=tau,gamma=gamma))
        for i in range(19):
            a = spread_on_Gs([f_graphs[index][0]],num,50,num_node,tau=tau,gamma=gamma)
            all_f_res_list.append(a)
            res_list += a 
            ax.plot(a[0][:50], a[2][:50],'-',alpha=0.3, color=rgb_navajowhite)
        res_list = res_list / 20        
        f_res_list.append(res_list)
        
        res_list_greedy_degree = spread_on_Gs([f_graphs[index][1]],num,50,num_node,tau=tau,gamma=gamma)
        all_f_res_list_greedy_degree.append(spread_on_Gs([f_graphs[index][1]],num,50,num_node,tau=tau,gamma=gamma))
        for i in range(19):
            a = spread_on_Gs([f_graphs[index][1]],num,50,num_node,tau=tau,gamma=gamma)
            all_f_res_list_greedy_degree.append(a)
            res_list_greedy_degree += a
            ax.plot(a[0][:50], a[2][:50],'-',alpha=0.15, color=rgb_lightcoral)
        res_list_greedy_degree = res_list_greedy_degree / 20
        f_res_list_greedy_degree.append(res_list_greedy_degree)
        
        res_list_random = spread_on_Gs([f_graphs[index][2]],num,50,num_node,tau=tau,gamma=gamma)
        all_f_res_list_random.append(spread_on_Gs([f_graphs[index][2]],num,50,num_node,tau=tau,gamma=gamma))
        for i in range(19):
            a = spread_on_Gs([f_graphs[index][2]],num,50,num_node,tau=tau,gamma=gamma)
            all_f_res_list_random.append(a)
            res_list_random += a 
            ax.plot(a[0][:50], a[2][:50],'-',alpha=0.15, color='skyblue')
        res_list_random = res_list_random / 20
        f_res_list_random.append(res_list_random)
    print(np.array(all_f_res_list_random).shape)   
    
    f_res_list = np.mean(np.array(all_f_res_list),axis=0)
    f_res_list_greedy_degree = np.mean(np.array(all_f_res_list_greedy_degree),axis=0)
    f_res_list_random = np.mean(np.array(all_f_res_list_random),axis=0)
    
    
    np.save('./results/tem_sir/sir'+net+'.npy',np.array([all_f_res_list_random,all_f_res_list_greedy_degree,all_f_res_list]))
    
    
    ax.plot(f_res_list_random[0][:50], f_res_list_random[2][:50],'-',label = r'Random selection',color='deepskyblue',linewidth=2.5)
    ax.plot(f_res_list_greedy_degree[0][:50], f_res_list_greedy_degree[2][:50],'-',label = r'Degree-greedy',color='r',linewidth=2.5)
    ax.plot(f_res_list[0][:50], f_res_list[2][:50],'-',label = r'Proposed method',color=r'darkorange',linewidth=2.5)
    ax.legend(fontsize=6,loc=1,frameon=False)
    ax.set_ylim(-0.05, 1)
    ax.set_yticks(np.arange(0, 1.0, 0.2))
    fig.savefig('./pics/01/fig_'+net+'_1.pdf')
# Out:
# 65
# (100, 4, 81)

# %%
#1 0.3
#0.2,0.01
#0.2.0.008 netscience 30 tortoise 25 weaver3
with plt.style.context(['ieee']):
    fig, ax = plt.subplots(1,1,figsize=(5,3))
    tau = 0.2
    gamma = 0.008
    num = 25
    num_node = nx.number_of_nodes(graph_dic[0].g) - len(results[0][0])
    print(num_node)
    f_graphs = get_reduced_graphs(graph_dic,results)
    
    
    f_res_list = []
    f_res_list_greedy_degree = []
    f_res_list_random = []
    for index in range(1):

        res_list = spread_on_Gs([f_graphs[index][0]],num,50,num_node,tau=tau,gamma=gamma)
        for i in range(99):
            a = spread_on_Gs([f_graphs[index][0]],num,50,num_node,tau=tau,gamma=gamma)
            res_list += a 
            ax.plot(a[0][:50], a[2][:50],'-',alpha=0.3, color='navajowhite')
        res_list = res_list / 100        
        f_res_list.append(res_list)
        
        res_list_greedy_degree = spread_on_Gs([f_graphs[index][1]],num,50,num_node,tau=tau,gamma=gamma)
        for i in range(99):
            a = spread_on_Gs([f_graphs[index][1]],num,50,num_node,tau=tau,gamma=gamma)
            res_list_greedy_degree += a
            ax.plot(a[0][:50], a[2][:50],'-',alpha=0.15, color='lightcoral')
        res_list_greedy_degree = res_list_greedy_degree / 100
        f_res_list_greedy_degree.append(res_list_greedy_degree)
        
        res_list_random = spread_on_Gs([f_graphs[index][2]],num,50,num_node,tau=tau,gamma=gamma)
        for i in range(99):
            a = spread_on_Gs([f_graphs[index][2]],num,50,num_node,tau=tau,gamma=gamma)
            res_list_random += a 
            ax.plot(a[0][:50], a[2][:50],'-',alpha=0.15, color='skyblue')
        res_list_random = res_list_random / 100
        f_res_list_random.append(res_list_random)
   # print(np.array(f_res_list).shape)   
    f_res_list = np.mean(np.array(f_res_list),axis=0)
    f_res_list_greedy_degree = np.mean(np.array(f_res_list_greedy_degree),axis=0)
    f_res_list_random = np.mean(np.array(f_res_list_random),axis=0)
    
    
    ax.plot(f_res_list_random[0][:50], f_res_list_random[2][:50],'-',label = r'Random selection',color='deepskyblue',linewidth=2.5)
    ax.plot(f_res_list_greedy_degree[0][:50], f_res_list_greedy_degree[2][:50],'-',label = r'Degree-greedy',color='r',linewidth=2.5)
    ax.plot(f_res_list[0][:50], f_res_list[2][:50],'-',label = r'Proposed method',color='darkorange',linewidth=2.5)
    ax.legend(fontsize=6,loc=1,frameon=False)
    fig.savefig('./pics/fig'+net+'0.pdf')

# %%
import matplotlib.pyplot as plt
import colorsys

def hsv_to_rgb(h, s, v):
    # colorsys accepts values from 0 to 1
    return colorsys.hsv_to_rgb(h/360, s/100, v/100)

# Example: Specify a color with 100% saturation, 50% hue (red), and 50% value (brightness)
hue = 36  # Example hue
saturation = 32  # Maximum saturation
value = 100  # Example value

rgb_color = hsv_to_rgb(hue, saturation, value)

# Use this color in a matplotlib plot
plt.plot([0, 1], [0, 1], color=rgb_color, linewidth=5)
plt.title("Line with specified saturation")
plt.show()

# %%
import matplotlib.pyplot as plt
import colorsys

# Function to convert HSL to RGB
# Hue: 0-360, Saturation: 0-100, Lightness: 0-100
def hsl_to_rgb(h, s, l):
    h /= 360
    s /= 100
    l /= 100
    return colorsys.hls_to_rgb(h, l, s)

# Specify HSL color
hsl_color = (45, 90, 87)  # Green in HSL
hsl_lightcoral = (3, 79, 78)  # navajowhite in HSL
hsl_navajowhite = (36, 90, 87)  # navajowhite in HSL

# Convert HSL to RGB
rgb_color = hsl_to_rgb(*hsl_color)

# Use the RGB color in Matplotlib
plt.figure()
plt.plot([0, 1], [0, 1], color=rgb_color, linewidth=8)
plt.title(f"Line with HSL color {hsl_color}")
plt.show()
